# %% [markdown]
# # Sentiment Analysis

# %%
import pandas as pd

df = pd.read_csv('/content/chat_dataset.csv')
df = df.drop(df.columns[1], axis=1)

df.head(50)
# Out:
#                                      message
# 0                 I really enjoyed the movie
# 1                      The food was terrible
# 2         I'm not sure how I feel about this
# 3                  The service was excellent
# 4                     I had a bad experience
# 5                    This is a great product
# 6                  I wouldn't recommend this
# 7                    The price is a bit high
# 8               The weather is perfect today
# 9                    The traffic is horrible
# 10            I'm feeling neutral about this
# 11                   The concert was amazing
# 12         The customer service was terrible
# 13                This book is a masterpiece
# 14              I regret buying this product
# 15        The view from here is breathtaking
# 16     I don't know what to think about this
# 17                The internet speed is slow
# 18                The museum was fascinating
# 19               The noise level is too high
# 20           I don't have an opinion on this
# 21     The hotel room was spacious and clean
# 22  The service at this restaurant was awful
# 23       This software is very user-friendly
# 24        The quality of the product is poor
# 25            I don't really care about this
# 26                     The beach was crowded
# 27  This is an excellent company to work for
# 28             The movie was a waste of time
# 29                  I'm undecided about this
# 30          The game was a complete disaster
# 31             The scenery here is beautiful
# 32             The speaker was very engaging
# 33                        I had a great time
# 34                This product is overpriced
# 35                   I'm indifferent to this
# 36           The performance was outstanding
# 37         The car broke down on the highway
# 38   I don't have strong feelings about this
# 39                    The food was delicious
# 40    The service at this hotel was terrible
# 41                     This phone is amazing
# 42               I'm not impressed with this
# 43          I have mixed feelings about this
# 44             The weather is terrible today
# 45             The book was a disappointment
# 46         I don't care one way or the other
# 47                   The hike was exhausting
# 48               This is a fantastic product
# 49         I don't know what to make of this

# %% [markdown]
# # Import NLTK for Sentiment Analysis of our CSV

# %%
# %pip install nltk

import nltk
#It will help us to determine the sentiment (positive, negative and neutral)
from nltk.sentiment import SentimentIntensityAnalyzer

nltk.download('vader_lexicon') # not darth Vader -> Valence Aware Dictionary and Sentiment Reasoner

sia = SentimentIntensityAnalyzer()
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk) (4.67.1)
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...

# %% [markdown]
# # Apply Sentiment Analysis to our CSV Column

# %%
df['message'] = df['message'].astype(str) #ensure our messages are treated like string
df['sentiment_scores'] = df['message'].apply(sia.polarity_scores)  #includes scores for 'neg' (negative), 'neu' (neutral), 'pos' (positive), and 'compound(Overall sentiment)'

#expand the scores into separate columns
df = pd.concat([df.drop(['sentiment_scores'], axis=1), df['sentiment_scores'].apply(pd.Series)], axis=1)
df.head()
# Out:
#                               message    neg    neu    pos  compound
# 0          I really enjoyed the movie  0.000  0.455  0.545    0.5563
# 1               The food was terrible  0.508  0.492  0.000   -0.4767
# 2  I'm not sure how I feel about this  0.246  0.754  0.000   -0.2411
# 3           The service was excellent  0.000  0.448  0.552    0.5719
# 4              I had a bad experience  0.636  0.364  0.000   -0.5423

# %%
# Adding the sentiment label based on compound score


def label_sentiment(compound):
  if compound >= 0.05:
    return 'Positive'
  elif compound <= -0.05:
    return 'Negative'
  else:
    return 'Neutral'

df['sentiment_label'] = df['compound'].apply(label_sentiment)

df.head(50)
# Out:
#                                      message    neg    neu    pos  compound  \
# 0                 I really enjoyed the movie  0.000  0.455  0.545    0.5563
# 1                      The food was terrible  0.508  0.492  0.000   -0.4767
# 2         I'm not sure how I feel about this  0.246  0.754  0.000   -0.2411
# 3                  The service was excellent  0.000  0.448  0.552    0.5719
# 4                     I had a bad experience  0.636  0.364  0.000   -0.5423
# 5                    This is a great product  0.000  0.423  0.577    0.6249
# 6                  I wouldn't recommend this  0.513  0.487  0.000   -0.2755
# 7                    The price is a bit high  0.000  1.000  0.000    0.0000
# 8               The weather is perfect today  0.000  0.519  0.481    0.5719
# 9                    The traffic is horrible  0.538  0.462  0.000   -0.5423
# 10            I'm feeling neutral about this  0.000  0.727  0.273    0.1280
# 11                   The concert was amazing  0.000  0.441  0.559    0.5859
# 12         The customer service was terrible  0.437  0.563  0.000   -0.4767
# 13                This book is a masterpiece  0.000  0.423  0.577    0.6249
# 14              I regret buying this product  0.483  0.517  0.000   -0.4215
# 15        The view from here is breathtaking  0.000  0.625  0.375    0.4588
# 16     I don't know what to think about this  0.000  1.000  0.000    0.0000
# 17                The internet speed is slow  0.000  1.000  0.000    0.0000
# 18                The museum was fascinating  0.000  0.462  0.538    0.5423
# 19               The noise level is too high  0.000  1.000  0.000    0.0000
# 20           I don't have an opinion on this  0.000  1.000  0.000    0.0000
# 21     The hotel room was spacious and clean  0.000  0.690  0.310    0.4019
# 22  The service at this restaurant was awful  0.333  0.667  0.000   -0.4588
# 23       This software is very user-friendly  0.000  1.000  0.000    0.0000
# 24        The quality of the product is poor  0.341  0.659  0.000   -0.4767
# 25            I don't really care about this  0.416  0.584  0.000   -0.4300
# 26                     The beach was crowded  0.000  1.000  0.000    0.0000
# 27  This is an excellent company to work for  0.000  0.654  0.346    0.5719
# 28             The movie was a waste of time  0.359  0.641  0.000   -0.4215
# 29                  I'm undecided about this  0.388  0.612  0.000   -0.2263
# 30          The game was a complete disaster  0.506  0.494  0.000   -0.6249
# 31             The scenery here is beautiful  0.000  0.506  0.494    0.5994
# 32             The speaker was very engaging  0.000  0.598  0.402    0.4005
# 33                        I had a great time  0.000  0.328  0.672    0.6249
# 34                This product is overpriced  0.000  1.000  0.000    0.0000
# 35                   I'm indifferent to this  0.375  0.625  0.000   -0.2023
# 36           The performance was outstanding  0.000  0.429  0.571    0.6124
# 37         The car broke down on the highway  0.318  0.682  0.000   -0.4215
# 38   I don't have strong feelings about this  0.351  0.649  0.000   -0.4023
# 39                    The food was delicious  0.000  0.448  0.552    0.5719
# 40    The service at this hotel was terrible  0.341  0.659  0.000   -0.4767
# 41                     This phone is amazing  0.000  0.441  0.559    0.5859
# 42               I'm not impressed with this  0.390  0.610  0.000   -0.3724
# 43          I have mixed feelings about this  0.000  1.000  0.000    0.0000
# 44             The weather is terrible today  0.437  0.563  0.000   -0.4767
# 45             The book was a disappointment  0.524  0.476  0.000   -0.5106
# 46         I don't care one way or the other  0.305  0.695  0.000   -0.3875
# 47                   The hike was exhausting  0.455  0.545  0.000   -0.3612
# 48               This is a fantastic product  0.000  0.455  0.545    0.5574
# 49         I don't know what to make of this  0.000  1.000  0.000    0.0000
#
#     sentiment_label
# 0          Positive
# 1          Negative
# 2          Negative
# 3          Positive
# 4          Negative
# 5          Positive
# 6          Negative
# 7           Neutral
# 8          Positive
# 9          Negative
# 10         Positive
# 11         Positive
# 12         Negative
# 13         Positive
# 14         Negative
# 15         Positive
# 16          Neutral
# 17          Neutral
# 18         Positive
# 19          Neutral
# 20          Neutral
# 21         Positive
# 22         Negative
# 23          Neutral
# 24         Negative
# 25         Negative
# 26          Neutral
# 27         Positive
# 28         Negative
# 29         Negative
# 30         Negative
# 31         Positive
# 32         Positive
# 33         Positive
# 34          Neutral
# 35         Negative
# 36         Positive
# 37         Negative
# 38         Negative
# 39         Positive
# 40         Negative
# 41         Positive
# 42         Negative
# 43          Neutral
# 44         Negative
# 45         Negative
# 46         Negative
# 47         Negative
# 48         Positive
# 49          Neutral
